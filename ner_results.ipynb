# %%
import run_model
from run_model import run_model

# %%
model_type = "domain" # choose checkpoint type
model_checkpoints = {
    "fast": "distilbert-base-uncased",
    "base": "bert-base-uncased",
    "domain": "emilyalsentzer/Bio_ClinicalBERT"
}

# %%
run_model("ner", model_checkpoints[model_type], epochs=30, classification="token", chunk_by="tokens")
# Out:
# Beginning data preprocessing
# Processed data written to ner_tokens200_train_for_token_classification.json and ner_tokens200_dev_for_token_classification.json
# Train label distribution:
# NoMedication: 266882
# MedicationStart: 6082
# MedicationContinue: 1008
# Dev label distribution:
# NoMedication: 41636
# MedicationStart: 1006
# MedicationContinue: 110
# Loading dataset into huggingface format
# Using custom data configuration default-939a9bc86228dccd
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /home/brentdevries/.cache/huggingface/datasets/json/default-939a9bc86228dccd/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# Tokenizing datasets using BERT
# ...
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Initializing BERT token classification model
# ...

# %%
run_model("ner", model_checkpoints[model_type], epochs=30, lr=2e-5, classification="token", chunk_by="tokens")
# Out:
# Beginning data preprocessing
# Processed data written to ner_tokens200_train_for_token_classification.json and ner_tokens200_dev_for_token_classification.json
# Train label distribution:
# NoMedication: 266882
# MedicationStart: 6082
# MedicationContinue: 1008
# Dev label distribution:
# NoMedication: 41636
# MedicationStart: 1006
# MedicationContinue: 110
# Loading dataset into huggingface format
# Using custom data configuration default-939a9bc86228dccd
# Reusing dataset json (/home/brentdevries/.cache/huggingface/datasets/json/default-939a9bc86228dccd/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Tokenizing datasets using BERT
# Loading cached processed dataset at /home/brentdevries/.cache/huggingface/datasets/json/default-939a9bc86228dccd/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b/cache-1e121caf2270fa0a.arrow
#   0%|          | 0/1 [00:00<?, ?ba/s]
# ...
